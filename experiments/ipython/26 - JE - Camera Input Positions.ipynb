# %% [markdown]
# ## Typical case (2 meters apart)
#
# ### people positions:
#
# A: -40.6, 0, -98.2
# B: -38.6, 0, -98.2
#
# ### camera positions:
#
# 'Name':"Apex Shot",
# 'Camera':np.array([-39.6, 0.7856504, -92.73151]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.220588, 0.3153169]),
# 'SB':np.array([-0.2205887, 0.3153169]),
#
# 'Name':"CloseApex Shot",
# 'Camera':np.array([-39.6, 1.22953, -94.2]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.3015709, 0.1928766]),
# 'SB':np.array([-0.3015718, 0.1928766]),
#
# 'Name':"TopDown Shot",
# 'Camera':np.array([-39.6, 5.050768, -95.70197]),
# 'Orientation':np.array([60, 180, 0]),
# 'SA':np.array([0.2838974, 0.2190374]),
# 'SB':np.array([-0.2838984, 0.2190374]),
#
# 'Name':"External Shot (of A)",
# 'Camera':np.array([-36.64378, 1.277935, -96.48122]),
# 'Orientation':np.array([0, 240, 0]),
# 'SA':np.array([0.137813, 0.1559604]),
# 'SB':np.array([-0.2411098, 0.2605692]),
#
# 'Name':"External Shot (of B)",
# 'Camera':np.array([-42.55621, 1.277935, -96.48122]),
# 'Orientation':np.array([0, 120, 0]),
# 'SA':np.array([0.2411121, 0.2605683]),
# 'SB':np.array([-0.137811, 0.1559602]),
#
# 'Name':"Internal Shot (of A)",
# 'Camera':np.array([-37.33841, 1.453164, -95.87225]),
# 'Orientation':np.array([0, 231.0895, 0]),
# 'SA':np.array([0.07157421, 0.07318914]),
# 'SB':np.array([-0.5029393, 0.1186907]),
#
# 'Name':"Internal Shot (of B)",
# 'Camera':np.array([-41.25859, 1.453164, -95.20197]),
# 'Orientation':np.array([0, 141.8296, 0]),
# 'SA':np.array([0.582644, 0.1051397]),
# 'SB':np.array([-0.07157129, 0.07318914]),

# %% [markdown]
# ## Extreme case - close (1 meter apart)
#
# ### people positions:
#
# A: -40.6, 0, -98.2
# B: -38.6, 0, -98.2
#
# ### camera positions:
#
# 'Name':"Apex Shot",
# 'Camera':np.array([-40.1, 0.7856504, -92.73151]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.110294, 0.3153169]),
# 'SB':np.array([-0.1102947, 0.3153169]),
#
# 'Name':"CloseApex Shot",
# 'Camera':np.array([-40.1, 1.269884, -94.2]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.1507854, 0.1712797]),
# 'SB':np.array([-0.1507864, 0.1712797]),
#
# 'Name':"TopDown Shot",
# 'Camera':np.array([-40.1, 5.050768, -95.70197]),
# 'Orientation':np.array([60, 180, 0]),
# 'SA':np.array([0.1419487, 0.2190374]),
# 'SB':np.array([-0.1419496, 0.2190374]),
#
# 'Name':"External Shot (of A)",
# 'Camera':np.array([-37.45629, 1.282868, -96.66637]),
# 'Orientation':np.array([0, 240, 0]),
# 'SA':np.array([0.08424723, 0.1881248]),
# 'SB':np.array([-0.1178586, 0.2496556]),
#
# 'Name':"External Shot (of B)",
# 'Camera':np.array([-42.74371, 1.282868, -96.66636]),
# 'Orientation':np.array([0, 120, 0]),
# 'SA':np.array([0.1178614, 0.2496552]),
# 'SB':np.array([-0.08424294, 0.1881248]),
#
# 'Name':"Internal Shot (of A)",
# 'Camera':np.array([-38.49765, 1.453164, -94.78877]),
# 'Orientation':np.array([0, 208.25, 0]),
# 'SA':np.array([0.07157481, 0.07318914]),
# 'SB':np.array([-0.2201237, 0.08277857]),
#
# 'Name':"Internal Shot (of B)",
# 'Camera':np.array([-42.45668, 1.453164, -95.39007]),
# 'Orientation':np.array([0, 137.9229, 0]),
# 'SA':np.array([0.1829085, 0.08756816]),
# 'SB':np.array([-0.0715732, 0.07318914]),

# %% [markdown]
# ## Extreme case - far (5 meters apart)
#
# ### people positions:
#
# A: -40.6, 0, -98.2
# B: -35.6, 0, -98.2
#
# ### camera positions:
#
# 'Name':"Apex Shot",
# 'Camera':np.array([-38.1, 0.7856504, -92.73151]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.5514708, 0.3153169]),
# 'SB':np.array([-0.5514708, 0.3153169]),
#
# 'Name':"CloseApex Shot",
# 'Camera':np.array([-38.1, 1.022828, -94.2]),
# 'Orientation':np.array([0, 180, 0]),
# 'SA':np.array([0.7539282, 0.3035027]),
# 'SB':np.array([-0.7539282, 0.3035027]),
#
# 'Name':"TopDown Shot",
# 'Camera':np.array([-38.1, 5.050768, -95.70197]),
# 'Orientation':np.array([60, 180, 0]),
# 'SA':np.array([0.7097445, 0.2190374]),
# 'SB':np.array([-0.7097445, 0.2190374]),
#
# 'Name':"External Shot (of A)",
# 'Camera':np.array([-32.74722, 1.245394, -95.12115]),
# 'Orientation':np.array([0, 240, 0]),
# 'SA':np.array([0.1822472, 0.08933854]),
# 'SB':np.array([-0.3730049, 0.1839309]),
#
# 'Name':"External Shot (of B)",
# 'Camera':np.array([-43.45277, 1.245394, -95.12115]),
# 'Orientation':np.array([0, 120, 0]),
# 'SA':np.array([0.3730053, 0.1839309]),
# 'SB':np.array([-0.1822464, 0.08933854]),
#
# 'Name':"Internal Shot (of A)",
# 'Camera':np.array([-37.55597, 1.453164, -95.59419]),
# 'Orientation':np.array([0, 226.0396, 0]),
# 'SA':np.array([0.07157326, 0.07318914]),
# 'SB':np.array([-9.729456, 0.7146447]),
#
# 'Name':"Internal Shot (of B)",
# 'Camera':np.array([-38.82706, 1.453164, -95.82463]),
# 'Orientation':np.array([0, 129.7515, 0]),
# 'SA':np.array([22.90688, 1.835289]),
# 'SB':np.array([-0.07157522, 0.07318914]),

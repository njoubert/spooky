# %%
import json

json_data=open("2m_transitionsskip2_1.json").read()

data = json.loads(json_data)

import numpy as np

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patches as mpatches
from matplotlib import gridspec

# graph in screen space
def drawScreenSetup():
    pylab.rcParams['figure.figsize'] = 9, 16
    #fig, ax = plt.subplots()

    plt.axes().set_aspect('equal')
    fig = plt.gcf() 
    
    # Set up plot size
    plt.axes().set_xlim(0, 1)
    plt.axes().set_ylim(0, 1)
    
    # Draw rule of thirds
    line_l = plt.Line2D([0.33, 0.33],[0, 1], c="black",alpha=0.3)
    line_r = plt.Line2D([0.66, 0.66],[0, 1], c="black",alpha=0.3)
    line_b = plt.Line2D([0, 1],[0.33, 0.33], c="black",alpha=0.3)
    line_t = plt.Line2D([0, 1],[0.66, 0.66], c="black",alpha=0.3)
    fig.gca().add_artist(line_l)
    fig.gca().add_artist(line_r)
    fig.gca().add_artist(line_b)
    fig.gca().add_artist(line_t)
    
    # Draw new interpolated positions
    t = np.linspace(0,1,num=len(screenPos0x))
    im = plt.scatter(screenPos0x,screenPos0y,c=t,cmap='Reds',linewidths=0)
    plt.scatter(screenPos1x,screenPos1y,c=t,cmap='Blues',linewidths=0)
    
    #fig.colorbar(im, ax=ax)
    #im.set_clim(0.0,1.0)

# %%
def getScreenData(prevShotType):
    shotType = ""
    for d in data:
        if d['camera']['isMoving']:
            if d['camera']['prevShotType'] == prevShotType:
                scale = d['camera']['scale']
                minPoint = (1.0 - scale)/2
                screenPos0x.append((d['players'][0]['screen'][0] - minPoint)/scale)
                screenPos0y.append((d['players'][0]['screen'][1] - minPoint)/scale)
                screenPos1x.append((d['players'][1]['screen'][0] - minPoint)/scale)
                screenPos1y.append((d['players'][1]['screen'][1] - minPoint)/scale)
                screenScale.append(scale)
                shotType = d['camera']['shotType']
    
    print prevShotType + " to " + shotType
    drawScreenSetup()

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("Apex")
# Out:
# Apex to External0

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("External0")
# Out:
# External0 to ExternalAbove1

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("ExternalAbove1")
# Out:
# ExternalAbove1 to Apex

# %%
json_data=open("2m_transitionsskip2_2.json").read()

data = json.loads(json_data)

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("ApexAbove")
# Out:
# ApexAbove to External1

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("External1")
# Out:
# External1 to Internal0

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("Internal0")
# Out:
# Internal0 to ApexAbove

# %%
json_data=open("2m_transitionsskip2.json").read()

data = json.loads(json_data)

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("CloseApex")
# Out:
# CloseApex to ExternalAbove0

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("ExternalAbove0")
# Out:
# ExternalAbove0 to Internal1

# %%
screenPos0x = []
screenPos0y = []
screenPos1x = []
screenPos1y = []
screenScale = []

getScreenData("Internal1")
# Out:
# Internal1 to CloseApex
